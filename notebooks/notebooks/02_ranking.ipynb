# %%
import pandas as pd
import numpy as np

# Cargar utilities TX ya procesado
df_tx = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\processed\utilities_tx.csv")

# Cargar subestaciones raw y filtrar TX
df_sub = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\raw\US Electric Power Transmission Substations.csv")
df_sub_tx = df_sub[df_sub["STATE"].astype(str).str.upper().str.strip() == "TX"].copy()

# Limpieza mínima útil para EDA
df_tx["zip"] = df_tx["zip"].astype(str).str.extract(r"(\d+)", expand=False).str.zfill(5)
df_tx["utility_name"] = df_tx["utility_name"].astype(str).str.strip()

rate_cols = ["comm_rate", "ind_rate", "res_rate"]
for c in rate_cols:
    df_tx[c] = pd.to_numeric(df_tx[c], errors="coerce")
df_tx[rate_cols] = df_tx[rate_cols].replace(0, np.nan)

df_sub_tx["LATITUDE"] = pd.to_numeric(df_sub_tx["LATITUDE"], errors="coerce")
df_sub_tx["LONGITUDE"] = pd.to_numeric(df_sub_tx["LONGITUDE"], errors="coerce")
df_sub_tx = df_sub_tx.dropna(subset=["LATITUDE", "LONGITUDE"])

print("✅ df_tx:", df_tx.shape)
print("✅ df_sub_tx:", df_sub_tx.shape)
# Out:
# ✅ df_tx: (3085, 10)
# ✅ df_sub_tx: (5314, 26)
# C:\Users\palmi\AppData\Local\Temp\ipykernel_11368\1463773740.py:8: DtypeWarning: Columns (7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sub = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\raw\US Electric Power Transmission Substations.csv")

# %%
[c for c in df_tx.columns if "county" in c.lower()]
# Out:
# []

# %% [markdown]
# CARGAR DATA

# %%
import pandas as pd
import numpy as np

df_tx = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\processed\utilities_tx.csv")
df_sub = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\raw\US Electric Power Transmission Substations.csv")

# Filtrar TX en subestaciones
df_sub_tx = df_sub[df_sub["STATE"].astype(str).str.upper().str.strip() == "TX"].copy()

# Limpieza mínima
df_tx["zip"] = df_tx["zip"].astype(str).str.extract(r"(\d+)", expand=False).str.zfill(5)
df_tx["utility_name"] = df_tx["utility_name"].astype(str).str.strip()

df_sub_tx["ZIP"] = df_sub_tx["ZIP"].astype(str).str.extract(r"(\d+)", expand=False).str.zfill(5)

print("Utilities TX:", df_tx.shape)
print("Substations TX:", df_sub_tx.shape)
# Out:
# Utilities TX: (3085, 10)
# Substations TX: (5314, 26)
# C:\Users\palmi\AppData\Local\Temp\ipykernel_11368\627781178.py:5: DtypeWarning: Columns (7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sub = pd.read_csv(r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\data\raw\US Electric Power Transmission Substations.csv")

# %% [markdown]
# UTILITIES POR ZIP

# %%
utilities_by_zip = (
    df_tx.groupby("zip")["utility_name"]
    .nunique()
    .reset_index(name="n_utilities")
)
utilities_by_zip.head()
# Out:
#      zip  n_utilities
# 0  73301            1
# 1  73344            1
# 2  75001            1
# 3  75002            2
# 4  75006            2

# %% [markdown]
# SUBESTACIONES POR ZIP

# %%
substations_by_zip = (
    df_sub_tx.groupby("ZIP")["ID"]
    .count()
    .reset_index(name="n_substations")
    .rename(columns={"ZIP": "zip"})
)
substations_by_zip.head()
# Out:
#      zip  n_substations
# 0  73949              1
# 1  75001              2
# 2  75006              6
# 3  75007              2
# 4  75009              5

# %% [markdown]
# UNIR TODO POR ZIP

# %%
df_zip = utilities_by_zip.merge(substations_by_zip, on="zip", how="left")
df_zip["n_substations"] = df_zip["n_substations"].fillna(0).astype(int)

print(df_zip.shape)
df_zip.head()
# Out:
# (1953, 3)
#      zip  n_utilities  n_substations
# 0  73301            1              0
# 1  73344            1              0
# 2  75001            1              2
# 3  75002            2              0
# 4  75006            2              6

# %% [markdown]
# CREAR SCORE Y RANKING

# %%
def minmax(s):
    s = s.astype(float)
    return (s - s.min()) / (s.max() - s.min() + 1e-9)

df_zip["utilities_norm"] = minmax(df_zip["n_utilities"])
df_zip["substations_norm"] = minmax(df_zip["n_substations"])

# pesos simples (podés ajustar después)
df_zip["tmps_score"] = 0.4 * df_zip["utilities_norm"] + 0.6 * df_zip["substations_norm"]

df_zip = df_zip.sort_values("tmps_score", ascending=False)
df_zip["rank"] = range(1, len(df_zip) + 1)

df_zip.head(20)
# Out:
#         zip  n_utilities  n_substations  utilities_norm  substations_norm  \
# 1664  79336            4             36        0.500000             0.900
# 972   77705            1             40        0.000000             1.000
# 1149  78155            5             19        0.666667             0.475
# 987   77807            7             10        1.000000             0.250
# 1002  77845            6             13        0.833333             0.325
# 1657  79323            3             26        0.333333             0.650
# 1681  79360            3             25        0.333333             0.625
# 1755  79549            2             29        0.166667             0.725
# 1778  79735            2             28        0.166667             0.700
# 991   77833            6              9        0.833333             0.225
# 947   77630            1             31        0.000000             0.775
# 1571  79072            3             22        0.333333             0.550
# 184   75455            4             17        0.500000             0.425
# 915   77523            1             29        0.000000             0.725
# 1553  79045            2             24        0.166667             0.600
# 1774  79720            3             19        0.333333             0.475
# 951   77640            1             27        0.000000             0.675
# 1009  77859            5              9        0.666667             0.225
# 1671  79346            4             13        0.500000             0.325
# 1567  79065            4             13        0.500000             0.325
#
#       tmps_score  rank
# 1664    0.740000     1
# 972     0.600000     2
# 1149    0.551667     3
# 987     0.550000     4
# 1002    0.528333     5
# 1657    0.523333     6
# 1681    0.508333     7
# 1755    0.501667     8
# 1778    0.486667     9
# 991     0.468333    10
# 947     0.465000    11
# 1571    0.463333    12
# 184     0.455000    13
# 915     0.435000    14
# 1553    0.426667    15
# 1774    0.418333    16
# 951     0.405000    17
# 1009    0.401667    18
# 1671    0.395000    19
# 1567    0.395000    20

# %% [markdown]
# GUARDAR RANKING FINAL

# %%
import os

out_dir = r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\outputs"
os.makedirs(out_dir, exist_ok=True)

df_zip.to_csv(os.path.join(out_dir, "texas_priority_zip_ranking.csv"), index=False)
print("✅ Guardado:", os.path.join(out_dir, "texas_priority_zip_ranking.csv"))
# Out:
# ✅ Guardado: C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\outputs\texas_priority_zip_ranking.csv

# %% [markdown]
# TOP UTILITIES DENTRO DE LOS ZIP MAS PRIORITARIOS

# %%
top_zips = df_zip.head(50)["zip"].tolist()

prospects = (
    df_tx[df_tx["zip"].isin(top_zips)]
    .groupby(["utility_name", "utility_type"])["zip"]
    .nunique()
    .sort_values(ascending=False)
    .reset_index(name="n_top_zips_covered")
)

prospects.head(30)
# Out:
#                           utility_name utility_type  n_top_zips_covered
# 0       Southwestern Public Service Co          IOU                  20
# 1       South Plains Electric Coop Inc      NON_IOU                  12
# 2                   Entergy Texas Inc.          IOU                  10
# 3          Lyntegar Electric Coop, Inc      NON_IOU                  10
# 4       Guadalupe Valley Elec Coop Inc      NON_IOU                   5
# 5       Big Country Electric Coop, Inc      NON_IOU                   5
# 6               City of Lubbock - (TX)      NON_IOU                   5
# 7        Bluebonnet Electric Coop, Inc      NON_IOU                   5
# 8       Southwestern Electric Power Co          IOU                   5
# 9         Mid-South Electric Coop Assn      NON_IOU                   5
# 10        Heart of Texas Electric Coop      NON_IOU                   4
# 11      Lamb County Electric Coop, Inc      NON_IOU                   4
# 12         Bartlett Electric Coop, Inc      NON_IOU                   4
# 13       Pedernales Electric Coop, Inc      NON_IOU                   4
# 14      North Plains Electric Coop Inc      NON_IOU                   3
# 15       Wharton County Elec Coop, Inc      NON_IOU                   3
# 16   Jackson Electric Coop, Inc - (TX)      NON_IOU                   3
# 17       Lea County Electric Coop, Inc      NON_IOU                   3
# 18       Lighthouse Electric Coop, Inc      NON_IOU                   3
# 19       Rio Grande Electric Coop, Inc      NON_IOU                   3
# 20      San Bernard Electric Coop, Inc      NON_IOU                   3
# 21      City of College Station - (TX)      NON_IOU                   3
# 22                City of Bryan - (TX)      NON_IOU                   3
# 23        Bailey County Elec Coop Assn      NON_IOU                   2
# 24         Upshur Rural Elec Coop Corp      NON_IOU                   2
# 25  Tri-County Electric Coop, Inc (OK)      NON_IOU                   2
# 26         Victoria Electric Coop, Inc      NON_IOU                   2
# 27      Panola-Harrison Elec Coop, Inc      NON_IOU                   2
# 28      Navasota Valley Elec Coop, Inc      NON_IOU                   2
# 29        Greenbelt Electric Coop, Inc      NON_IOU                   2

# %%
df_zip.shape
# Out:
# (1953, 7)

# %%
import os

top_zips = df_zip.head(50)["zip"].astype(str).tolist()

prospects = (
df_tx[df_tx["zip"].astype(str).isin(top_zips)]
.groupby(["utility_name", "utility_type", "ownership"])["zip"]
.nunique()
.sort_values(ascending=False)
.reset_index(name="n_top_zips_covered")
 )

out_dir = r"C:\Users\palmi\OneDrive\Escritorio\Bootcamp\texas-utility-capstone\outputs"
os.makedirs(out_dir, exist_ok=True)

prospects.to_csv(os.path.join(out_dir, "top_prospects_in_top50_zips.csv"), index=False)
prospects.head(20)
# Out:
#                          utility_name utility_type       ownership  \
# 0      Southwestern Public Service Co          IOU  Investor Owned
# 1      South Plains Electric Coop Inc      NON_IOU     Cooperative
# 2                  Entergy Texas Inc.          IOU  Investor Owned
# 3         Lyntegar Electric Coop, Inc      NON_IOU     Cooperative
# 4      Guadalupe Valley Elec Coop Inc      NON_IOU     Cooperative
# 5      Big Country Electric Coop, Inc      NON_IOU     Cooperative
# 6              City of Lubbock - (TX)      NON_IOU       Municipal
# 7       Bluebonnet Electric Coop, Inc      NON_IOU     Cooperative
# 8      Southwestern Electric Power Co          IOU  Investor Owned
# 9        Mid-South Electric Coop Assn      NON_IOU     Cooperative
# 10       Heart of Texas Electric Coop      NON_IOU     Cooperative
# 11     Lamb County Electric Coop, Inc      NON_IOU     Cooperative
# 12        Bartlett Electric Coop, Inc      NON_IOU     Cooperative
# 13      Pedernales Electric Coop, Inc      NON_IOU     Cooperative
# 14     North Plains Electric Coop Inc      NON_IOU     Cooperative
# 15      Wharton County Elec Coop, Inc      NON_IOU     Cooperative
# 16  Jackson Electric Coop, Inc - (TX)      NON_IOU     Cooperative
# 17      Lea County Electric Coop, Inc      NON_IOU     Cooperative
# 18      Lighthouse Electric Coop, Inc      NON_IOU     Cooperative
# 19      Rio Grande Electric Coop, Inc      NON_IOU     Cooperative
#
#     n_top_zips_covered
# 0                   20
# 1                   12
# 2                   10
# 3                   10
# 4                    5
# 5                    5
# 6                    5
# 7                    5
# 8                    5
# 9                    5
# 10                   4
# 11                   4
# 12                   4
# 13                   4
# 14                   3
# 15                   3
# 16                   3
# 17                   3
# 18                   3
# 19                   3
